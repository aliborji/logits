10: 0.19099491648511258
10: 0.20261437908496732
100: 0.19753086419753085
100: 0.27450980392156865
500: 0.25054466230936817
500: 0.33042846768336964
1000: 0.24328249818445896
1000: 0.36310820624546114
2000: 0.2512708787218591
2000: 0.3660130718954248
'''

LN_trained_un_cross = [0.18518518518518517,		0.1626724763979666, 0.1466957153231663]
RBF_trained_un_cross = [0.2411038489469862	,	0.19099491648511258, 0.13870733478576616]

# %%
data = [float(x) for x in N_pertained_un.split()[1::2]]
SVM_l = np.array(data).reshape(6,-1)[:,::2]
SVM_r = np.array(data).reshape(6,-1)[:,1::2]

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('trained all weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# Original
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_trained_n, LN_trained_un]], yerr=[np.array(x).std() for x in [LN_trained_n, LN_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_trained_n, RBF_trained_un]], yerr=[np.array(x).std() for x in [RBF_trained_n, RBF_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained all weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()


# Original

fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_trained_n_cross, LN_trained_un_cross]], yerr=[np.array(x).std() for x in [LN_trained_n_cross, LN_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_trained_n_cross, RBF_trained_un_cross]], yerr=[np.array(x).std() for x in [RBF_trained_n_cross, RBF_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained all weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .101, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Trained weights of the last layer

# %%
# Normalized
# Run 1, 2 ..
LN_last_trained_n = [0.12854030501089325,	0.1111111111111111,		0.11256354393609296,	0.1009440813362382	,	0.11909949164851126	,	0.11038489469862019	, 0.10820624546114742]
RBF_last_trained_n = [0.19389978213507625	,0.16993464052287582	,0.21931735657225854	,0.17138707334785766,		0.11909949164851126	,	0.19753086419753085, 0.1830065359477124]

N_last_trained_n = '''
10: 0.1336238198983297
10: 0.1205519244734931
100: 0.12854030501089325
100: 0.16485112563543936
500: 0.14814814814814814
500: 0.22004357298474944
1000: 0.11328976034858387
1000: 0.22948438634713145
2000: 0.1394335511982571
2000: 0.24255628177196806

10: 0.15250544662309368
10: 0.1299927378358751
100: 0.12926652142338416
100: 0.15831517792302105
500: 0.1111111111111111
500: 0.14814814814814814
1000: 0.1111111111111111
1000: 0.17429193899782136
2000: 0.1111111111111111
2000: 0.19607843137254902

10: 0.14960058097313
10: 0.13144517066085692
100: 0.13507625272331156
100: 0.12636165577342048
500: 0.11256354393609296
500: 0.16993464052287582
1000: 0.11038489469862019
1000: 0.18010167029774873
2000: 0.1111111111111111
2000: 0.18809005083514888

'''

LN_last_trained_n_cross = [0.0915032679738562	,	0.09949164851125636, 0.10384894698620188]
RBF_last_trained_n_cross = [0.14887436456063907,	0.1365286855482934, 0.09731299927378359]

# %%
data = [float(x) for x in N_last_trained_n.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]  


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('trained last layer weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .115, r'chance level', fontsize=15)

plt.show()

# %%
# UnNormalized
# Run 1, 2 ..
LN_last_trained_un = [0.3333333333333333,	0.280319535221496,	0.2585330428467683	,	0.3006535947712418	,	0.32679738562091504, 0.2984749455337691]
RBF_last_trained_un = [0.477124183006536	,	0.42846768336964414	,0.43500363108206247	,		0.4989106753812636	,	0.4400871459694989, 0.46695715323166304]

N_last_trained_un = '''
10: 0.11183732752360204
10: 0.2113289760348584
100: 0.2476397966594045
100: 0.3609295570079884
500: 0.2374727668845316
500: 0.4480755265068991
1000: 0.3021060275962237
1000: 0.48366013071895425
2000: 0.32389251997095136
2000: 0.49818445896877267

10: 0.14596949891067537
10: 0.10893246187363835
100: 0.2570806100217865
100: 0.3028322440087146
500: 0.29048656499636893
500: 0.4045025417574437
1000: 0.3202614379084967
1000: 0.43137254901960786
2000: 0.31445170660856936
2000: 0.4357298474945534

10: 0.1568627450980392
10: 0.13435003631082063
100: 0.21713870733478577
100: 0.36673928830791575
500: 0.21568627450980393
500: 0.4408133623819898
1000: 0.25780682643427744
1000: 0.4553376906318083
2000: 0.2962962962962963
2000: 0.46405228758169936

'''

LN_last_trained_un_cross = [0.19753086419753085,	0.10239651416122005 , 0.18010167029774873]
RBF_last_trained_un_cross = [0.32461873638344224,	0.25562817719680464, 0.2774146695715323]

# %%
data = [float(x) for x in N_last_trained_un.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('trained last layer weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_last_trained_n, LN_last_trained_un]], yerr=[np.array(x).std() for x in [LN_last_trained_n, LN_last_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_last_trained_n, RBF_last_trained_un]], yerr=[np.array(x).std() for x in [RBF_last_trained_n, RBF_last_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained last layer weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()


fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_last_trained_n_cross, LN_last_trained_un_cross]], yerr=[np.array(x).std() for x in [LN_last_trained_n_cross, LN_last_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_last_trained_n_cross, RBF_last_trained_un_cross]], yerr=[np.array(x).std() for x in [RBF_last_trained_n_cross, RBF_last_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained last layer weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Pretrained weights

# %%
# —————————— No Training ———————————
# Pertained and the final linear classification layer not trained [just reformatting the net]pertained = True)
# Random weights (loading models with pertained = True). [no training]

# Normalized
# Run 1, 2 ..
LN_pretrained_n = [0.11183732752360204,	0.13725490196078433	,0.12418300653594772,	0.11982570806100218	,	0.12200435729847495	,0.16122004357298475,0.11692084241103849, 0.15758896151053015, 0.1859114015976761]
RBF_pretrained_n = [0.2774146695715323,	0.2737835875090777	,	0.24183006535947713,	0.25054466230936817	,0.1830065359477124	,	0.20043572984749455, 0.2716049382716049, 0.16339869281045752, 0.26143790849673204]

N_pertained_n = '''
10: 0.1539578794480755
10: 0.16630355846042122
100: 0.10457516339869281
100: 0.16848220769789396
500: 0.1111111111111111
500: 0.26870007262164125
1000: 0.11038489469862019
1000: 0.2665214233841685
2000: 0.1111111111111111
2000: 0.2716049382716049

10: 0.1430646332607117
10: 0.11038489469862019
100: 0.11183732752360204
100: 0.15468409586056645
500: 0.10893246187363835
500: 0.1626724763979666
1000: 0.1437908496732026
1000: 0.16993464052287582
2000: 0.12418300653594772
2000: 0.15904139433551198


10: 0.09949164851125636
10: 0.12490922294843863
100: 0.14596949891067537
100: 0.2411038489469862
500: 0.12418300653594772
500: 0.25635439360929557
1000: 0.11183732752360204
1000: 0.2549019607843137
2000: 0.10530137981118373
2000: 0.262164124909223
'''

# %%
data = [float(x) for x in N_pertained_n.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]  

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# Pertained and the final linear classification layer not trained [just reformatting the net]pertained = True)
# Random weights (loading models with pertained = True). [no training]

# UnNormalized
LN_pretrained_un = [0.37400145243282495	,0.41249092229484385,	0.4756717501815541,	0.4691358024691358, 0.33405954974582425, 0.4117647058823529]
RBF_pretrained_un = [0.40305010893246185,	0.47421931735657225	,0.5257806826434277,		0.485838779956427, 0.3841684822076979, 0.45461147421931736]

N_pertained_un = '''
10: 0.2113289760348584
10: 0.2403776325344953
100: 0.34713144517066086
100: 0.38198983297022515
500: 0.4277414669571532
500: 0.48002904865649965
1000: 0.46042120551924476
1000: 0.47639796659404504
2000: 0.4647785039941903
2000: 0.48148148148148145

10: 0.12490922294843863
10: 0.1539578794480755
100: 0.27596223674655046
100: 0.289760348583878
500: 0.28540305010893247
500: 0.364560639070443
1000: 0.3100944081336238
1000: 0.37037037037037035
2000: 0.3137254901960784
2000: 0.3783587509077705

10: 0.20987654320987653
10: 0.2113289760348584
100: 0.4001452432824982
100: 0.41466957153231665
500: 0.39288307915758897
500: 0.4190268700072622
1000: 0.4328249818445897
1000: 0.4567901234567901
2000: 0.42193173565722586
2000: 0.4524328249818446

'''

# %%
data = [float(x) for x in N_pertained_un.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]

# %%
# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Random weights

# %%
# Random weights (loading models with pertained = False). [no training]  

# Normalized
LN_random_n = [0.6180101670297748	,0.6078431372549019,	0.7443718228031954,	0.6361655773420479,		0.5722585330428468,		0.7763253449527959	,	0.7247639796659404, 0.6347131445170661]
RBF_random_n = [0.6673928830791576,	0.7400145243282498	,	0.7770515613652869,	0.7472766884531591,	0.7443718228031954		,0.8395061728395061	,	0.8053740014524329, 0.7668845315904139]

N_random_n = '''
10 0.18518518518518517	
10 0.18445896877269427
100 0.14742193173565724	
100 0.2374727668845316
500 0.3151779230210603	
500 0.5250544662309368	
1000 0.514161220043573	
1000 0.5468409586056645
2000 0.6223674655047204	
2000 0.6688453159041394

10: 0.3812636165577342
10: 0.38344226579520696
100: 0.1111111111111111
100: 0.5715323166303559
500: 0.5461147421931736
500: 0.7334785766158315
1000: 0.44371822803195354
1000: 0.7516339869281046
2000: 0.6201888162672476
2000: 0.7741466957153231

10: 0.39796659404502543
10: 0.3681917211328976
100: 0.28830791575889614
100: 0.7225853304284677
500: 0.10965867828612927
500: 0.7327523602033406
1000: 0.19099491648511258
1000: 0.7421931735657226
2000: 0.3369644153957879
2000: 0.7559912854030502

10: 0.439360929557008
10: 0.4132171387073348
100: 0.5134350036310821
100: 0.6949891067538126
500: 0.5490196078431373
500: 0.739288307915759
1000: 0.5940450254175744
1000: 0.7421931735657226
2000: 0.1140159767610748
2000: 0.7523602033405955

'''


data = [float(x) for x in N_random_n.split()[1::2]]
SVM_l = np.array(data).reshape(4,-1)[:,::2]
SVM_r = np.array(data).reshape(4,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# Random weights (loading models with pertained = False). [no training]  

# UnNormalized
LN_random_un = [0.9615105301379812 	,	0.8126361655773421	,	0.8286129266521424, 0.831517792302106,	0.9019607843137255]
RBF_random_un = [ 0.869281045751634	,	0.7349310094408134	,	0.7472766884531591, 0.7908496732026143	,	0.8257080610021786	]

N_random_un = '''
10	0.18155410312273057	
10	0.19462599854756718
100	0.570079883805374	
100	0.46695715323166304
500	0.5780682643427741	
500	0.47421931735657225	
1000	0.5816993464052288		
1000	0.4749455337690632
2000	0.6928104575163399		
2000	0.5882352941176471

10: 0.2679738562091503
10: 0.17647058823529413
100: 0.49310094408133626
100: 0.48148148148148145
500: 0.5722585330428468
500: 0.5119825708061002
1000: 0.5751633986928104
1000: 0.5134350036310821
2000: 0.5664488017429193
2000: 0.5228758169934641



10: 0.3355119825708061
10: 0.2222222222222222
100: 0.5315904139433552
100: 0.4364560639070443
500: 0.5744371822803195
500: 0.5933188090050835
1000: 0.5787944807552651
1000: 0.5816993464052288
2000: 0.6790123456790124
2000: 0.6042120551924474

'''


data = [float(x) for x in N_random_un.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()


fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_pretrained_n, LN_pretrained_un]], yerr=[np.array(x).std() for x in [LN_pretrained_n, LN_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_pretrained_n, RBF_pretrained_un]], yerr=[np.array(x).std() for x in [RBF_pretrained_n, RBF_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# # Transfer

# %%
# ************************************************
# Same network for different initialization. 
# Use a classifier on one initialization and then test on a different initialization!!!

# Random weights (loading models with pertained = False). [no training]

# normalized
# Run 1, 2 ..
LN_random_n = [0.18082788671023964,	0.22657952069716775,	0.03994190268700073	,0.12200435729847495,	0.11546840958605664]
RBF_random_n = [0.38344226579520696	,0.00944081336238199,	0.0878721859114016,	0.14451706608569354,	0.17647058823529413]

# Un- normalized
# Run 1, 2 ..
LN_random_un =  [0.23021060275962238,	0.13798111837327523	,	0.005083514887436456,	0.2875816993464052	,	0.19535221496005808	,0.2926652142338417]
RBF_random_un  =	[0.27523602033405953,	0.2839506172839506,		0.14451706608569354,	0.32171387073347857,		0.35439360929557007	,0.3028322440087146]



# Random weights (loading models with pertained = True). [no training]

# normalized
# Run 1, 2 ..
LN_pretrained_n =	[0.11183732752360204,		0.12273057371096587,	0.16339869281045752]
RBF_pretrained_n =[0.10239651416122005	,	0.07988380537400146,	0.19607843137254902]


# Un- normalized
# Run 1, 2 ..
LN_pretrained_un = [0.28685548293391433	,0.09731299927378359,	0.08351488743645606,	0.1728395061728395]
RBF_pretrained_un =[0.38344226579520696	,0.10965867828612927,	0.11764705882352941,	0.2018881626724764]



fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_pretrained_n, LN_pretrained_un]], yerr=[np.array(x).std() for x in [LN_pretrained_n, LN_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_pretrained_n, RBF_pretrained_un]], yerr=[np.array(x).std() for x in [RBF_pretrained_n, RBF_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()
