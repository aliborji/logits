# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Original CIFAR 10 results

# %% [markdown]
# ### Trained weights of the last layer

# %%
# Normalized
# Run 1, 2 ..
LN_last_trained_n = [0.1854076298520743, 0.11845178511845178]
RBF_last_trained_n = [0.2760538316093872, 0.18051384718051386]

N_last_trained_n = '''
10: 0.17339561784006227
10: 0.11133355577800022
100: 0.17595373150928706
100: 0.13068624179735291
500: 0.13558002446891335
500: 0.1770659548437326
1000: 0.19308197085974863
1000: 0.21844066288510733
2000: 0.1781781781781782
2000: 0.22845067289511733


10: 0.11845178511845178
10: 0.1111111111111111
100: 0.13713713713713713
100: 0.1166722277833389
500: 0.14937159381603826
500: 0.12990768546324102
1000: 0.12145478812145478
1000: 0.13747080413747081
2000: 0.1272383494605717
2000: 0.14970526081637192

'''

LN_last_trained_n_cross = [0.12512512512512514, 0.10844177510844177]
RBF_last_trained_n_cross = [	0.13880547213880548, 0.11644978311644978]

# %%
data = [float(x) for x in N_last_trained_n.split()[1::2]]
SVM_l = np.array(data).reshape(2,-1)[:,::2]
SVM_r = np.array(data).reshape(2,-1)[:,1::2]  


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('trained last layer weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .115, r'chance level', fontsize=15)

plt.show()

# %%
# UnNormalized
# Run 1, 2 ..
LN_last_trained_un = [0.3912801690579468, 0.2351240129017907]
RBF_last_trained_un = [0.28005783561339115, 0.23745968190412634]

N_last_trained_un = '''
10: 0.10933155377599822
10: 0.10054498943387832
100: 0.23034145256367478
100: 0.11277944611277944
500: 0.33500166833500167
500: 0.15915915915915915
1000: 0.3605828050272495
1000: 0.20687354020687354
2000: 0.3771549327104883
2000: 0.22233344455566678

10: 0.12012012012012012
10: 0.1111111111111111
100: 0.1612723834946057
100: 0.1206762317873429
500: 0.19130241352463576
500: 0.1578244911578245
1000: 0.20831943054165275
1000: 0.17217217217217218
2000: 0.2222222222222222
2000: 0.19297074852630408

'''

LN_last_trained_un_cross = [0.11556000444889333,  0.11233455677900123]
RBF_last_trained_un_cross = [	0.1891891891891892, 0.11411411411411411	]

# %%
data = [float(x) for x in N_last_trained_un.split()[1::2]]
SVM_l = np.array(data).reshape(2,-1)[:,::2]
SVM_r = np.array(data).reshape(2,-1)[:,1::2]

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('trained last layer weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_last_trained_n, LN_last_trained_un]], yerr=[np.array(x).std() for x in [LN_last_trained_n, LN_last_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_last_trained_n, RBF_last_trained_un]], yerr=[np.array(x).std() for x in [RBF_last_trained_n, RBF_last_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained last layer weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()


fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_last_trained_n_cross, LN_last_trained_un_cross]], yerr=[np.array(x).std() for x in [LN_last_trained_n_cross, LN_last_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_last_trained_n_cross, RBF_last_trained_un_cross]], yerr=[np.array(x).std() for x in [RBF_last_trained_n_cross, RBF_last_trained_un_cross]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('trained last layer weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Pretrained weights

# %%
# Pertained and the final linear classification layer not trained [just reformatting the net]pertained = True)
# Random weights (loading models with pertained = True). [no training]

# Normalized
# Run 1, 2 ..
LN_pretrained_n = [0.12657101545990435,	0.1798465131798465	,	0.14336558781003225]
RBF_pretrained_n = [0.6262929596262929	,	0.6850183516850183,		0.7091535980424869]

N_pertained = '''
10: 0.17728839951062172
10: 0.11133355577800022
100: 0.15548882215548882
100: 0.3602491380269158
500: 0.18974530085641197
500: 0.48403959515070627
1000: 0.15693471249026805
1000: 0.4953842731620509
2000: 0.12679346012679346
2000: 0.5656767878990101


10: 0.20064508953397842
10: 0.1961961961961962
100: 0.19408297186074963
100: 0.3198754309865421
500: 0.2573684795907018
500: 0.5382048715382048
1000: 0.21944166388610833
1000: 0.5957068179290401
2000: 0.24769213658102546
2000: 0.6466466466466466


10: 0.18262707151596042
10: 0.15326437548659771
100: 0.2351240129017907
100: 0.43688132577021466
500: 0.23723723723723725
500: 0.5732399065732399
1000: 0.2225558892225559
1000: 0.6177288399510622
2000: 0.16494272049827605
2000: 0.6625514403292181
'''

# %%
data = [float(x) for x in N_pertained.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]

# %%
# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# Pertained and the final linear classification layer not trained [just reformatting the net]pertained = True)
# Random weights (loading models with pertained = True). [no training]

# UnNormalized
LN_pretrained_un = [	0.7814481147814482	,	0.8421755088421755]
RBF_pretrained_un = [0.8665331998665332	,	0.9080191302413525]

N_pertained_un = '''
10: 0.36614392169947724
10: 0.2599265932599266
100: 0.71215660104549
100: 0.7209431653876098
500: 0.7350684017350684
500: 0.8113669224780335
1000: 0.7558669780892003
1000: 0.8409520631742854
2000: 0.7570904237570905
2000: 0.8455121788455122

10: 0.401512623734846
10: 0.4134134134134134
100: 0.7385162940718496
100: 0.7475253030808586
500: 0.8118118118118118
500: 0.8745412078745413
1000: 0.8512957401846291
1000: 0.8953397842286731
2000: 0.8425091758425092
2000: 0.8967856745634524
'''

# %%
data = [float(x) for x in N_pertained_un.split()[1::2]]
SVM_l = np.array(data).reshape(2,-1)[:,::2]
SVM_r = np.array(data).reshape(2,-1)[:,1::2]

# %%
# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Random weights

# %%
# Random weights (loading models with pertained = False). [no training]  

# Normalized
LN_random_n = [0.905127349571794,	0.9063507952396841	,	0.914136358580803,	0.8667556445334224]
RBF_random_n = [0.987987987987988	,	0.9768657546435324,		0.9822044266488711	,	0.9696363029696363]

N_random = '''
10: 0.21933044155266376
10: 0.30274719163608055
100: 0.832054276498721
100: 0.9508397286175064
500: 0.9338227116004894
500: 0.9805360916472028
1000: 0.924924924924925
1000: 0.9818707596485374
2000: 0.9205872539205873
2000: 0.9848737626515405 

10: 0.5588922255588922
10: 0.5542208875542209
100: 0.9040151262373485
100: 0.9427204982760539
500: 0.9210321432543654
500: 0.9558447336225114
1000: 0.932154376598821
1000: 0.9758647536425314
2000: 0.9066844622400178
2000: 0.9784228673117562
'''


data = [float(x) for x in N_random.split()[1::2]]
SVM_l = np.array(data).reshape(2,-1)[:,::2]
SVM_r = np.array(data).reshape(2,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# Random weights (loading models with pertained = False). [no training]  

# UnNormalized
LN_random_un = [0.9975531086642198,	0.9630741852964075	,	0.9946613279946613]
RBF_random_un = [ 0.8835502168835502,	0.8816594372149927	,	0.8828828828828829]

N_random_un = '''
10: 0.6485374263152041
10: 0.4408853297742187
100: 0.6490935379824269
100: 0.5114002891780669
500: 0.7136024913802692
500: 0.6308530752975198
1000: 0.7630964297630964
1000: 0.6480925369814259
2000: 0.7714381047714381
2000: 0.8767656545434324



10: 0.35012790568346125
10: 0.3117562006450895
100: 0.6319652986319653
100: 0.48837726615504395
500: 0.6575464353242131
500: 0.6326326326326326
1000: 0.7574240907574241
1000: 0.648314981648315
2000: 0.880102324546769
2000: 0.7648759870982094
'''


data = [float(x) for x in N_random_un.split()[1::2]]
SVM_l = np.array(data).reshape(2,-1)[:,::2]
SVM_r = np.array(data).reshape(2,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_pretrained_n, LN_pretrained_un]], yerr=[np.array(x).std() for x in [LN_pretrained_n, LN_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_pretrained_n, RBF_pretrained_un]], yerr=[np.array(x).std() for x in [RBF_pretrained_n, RBF_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# # Transfer

# %%
# ************************************************
# Same network for different initialization. 
# Use a classifier on one initialization and then test on a different initialization!!!

# Random weights (loading models with pertained = False). [no training]

# normalized
# Run 1, 2 ..
LN_random_n = [0.02958514069625181,	0.12701590479368258]
RBF_random_n = [	0.10977644310977644,	0.10632855077299522]

# Un- normalized
# Run 1, 2 ..
LN_random_un =  [0.21273238434954606,	0.3088644199755311]
RBF_random_un  =	[0.3665477658876999	,	0.26704482260037815]

# Random weights (loading models with pertained = True). [no training]

# normalized
# Run 1, 2 ..
LN_pretrained_n =	[0.10666221777332889,	0.10643977310643978]
RBF_pretrained_n =[	0.08686464242019798,	0.07118229340451562]


# Un- normalized
# Run 1, 2 ..
LN_pretrained_un = [0.13891669447225002,	0.08397286175063953]
RBF_pretrained_un =[	0.1386942498053609,		0.11433655878100323]



fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_pretrained_n, LN_pretrained_un]], yerr=[np.array(x).std() for x in [LN_pretrained_n, LN_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_pretrained_n, RBF_pretrained_un]], yerr=[np.array(x).std() for x in [RBF_pretrained_n, RBF_pretrained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights (transfer)')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(1, .12, r'chance level', fontsize=15)

plt.show()
