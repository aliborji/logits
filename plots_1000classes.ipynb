# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # 1000 classes (applying the orig imagenet model to the datasets)

# %% [markdown]
# # Over Bees

# %% [markdown]
# ### Pretrained

# %%
# trained =  True # loads models with random weight and not pretrained weights
# case = 'normalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'Bees' #'CIFAR10'

# %%
# Normalized
# Run 1, 2 ..
LN_trained_n = [0.9172113289760349,	0.9215686274509803,		0.9135802469135802]
RBF_trained_n = [0.4037763253449528,	0.4045025417574437,		0.40522875816993464]


N_pertained = '''
10: 0.3042846768336964
10: 0.1111111111111111
100: 0.7915758896151053
100: 0.34350036310820625
500: 0.8721859114015976
500: 0.3914306463326071
1000: 0.8910675381263616
1000: 0.39796659404502543
2000: 0.9143064633260711
2000: 0.4037763253449528


10: 0.3297022512708787
10: 0.1111111111111111
100: 0.7937545388525781
100: 0.3681917211328976
500: 0.8729121278140886
500: 0.39215686274509803
1000: 0.8990559186637618
1000: 0.3972403776325345
2000: 0.9164851125635439
2000: 0.4037763253449528

10: 0.32679738562091504
10: 0.11764705882352941
100: 0.7901234567901234
100: 0.35947712418300654
500: 0.8620188816267248
500: 0.39433551198257083
1000: 0.8946986201888163
1000: 0.4008714596949891
2000: 0.9135802469135802
2000: 0.40305010893246185
'''

# %%
data = [float(x) for x in N_pertained.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]  


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# # global params
# trained =  True # loads models with random weight and not pretrained weights
# case = 'unnormalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'Bees' #'CIFAR10'

# %%
# UnNormalized
# Run 1, 2 ..
LN_trained_un = [0.9832970225127088,	0.9825708061002179,	0.9832970225127088]
RBF_trained_un = [0.1430646332607117,	0.1394335511982571,	0.1466957153231663] 

N_pertained_un = '''
10: 0.25199709513435004
10: 0.1111111111111111
100: 0.7124183006535948
100: 0.1111111111111111
500: 0.9397240377632534
500: 0.1111111111111111
1000: 0.9629629629629629
1000: 0.1111111111111111
2000: 0.9796659404502541
2000: 0.1111111111111111

10: 0.39215686274509803
10: 0.11183732752360204
100: 0.7676107480029049
100: 0.1111111111111111
500: 0.9448075526506899
500: 0.1111111111111111
1000: 0.9658678286129266
1000: 0.1111111111111111
2000: 0.9840232389251997
2000: 0.1111111111111111

10: 0.4517066085693537
10: 0.1111111111111111
100: 0.7501815541031227
100: 0.1111111111111111
500: 0.9498910675381264
500: 0.1111111111111111
1000: 0.9665940450254176
1000: 0.1111111111111111
2000: 0.9847494553376906
2000: 0.1111111111111111
'''

# %%
data = [float(x) for x in N_pertained_un.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# Original
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_trained_n, LN_trained_un]], yerr=[np.array(x).std() for x in [LN_trained_n, LN_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_trained_n, RBF_trained_un]], yerr=[np.array(x).std() for x in [RBF_trained_n, RBF_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(.5, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Random weights

# %%
# # global params
# trained =  False # loads models with random weight and not pretrained weights
# case = 'normalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'Bees' #'CIFAR10'

# %%
# Random weights (loading models with pertained = False). [no training]  

# Normalized
LN_random_n = [0.9731299927378358,	0.9782135076252724,	0.9571532316630356]
RBF_random_n = [0.9615105301379812,	 0.9404502541757443	,	0.9172113289760349]

N_random = '''
10: 0.6143790849673203
10: 0.6717501815541032
100: 0.9360929557007989
100: 0.9375453885257807
500: 0.9731299927378358
500: 0.9520697167755992
1000: 0.9782135076252724
1000: 0.9564270152505446
2000: 0.9745824255628177
2000: 0.9615105301379812

10: 0.4698620188816267
10: 0.4408133623819898
100: 0.9477124183006536
100: 0.8627450980392157
500: 0.971677559912854
500: 0.9070442992011619
1000: 0.9694989106753813
1000: 0.9281045751633987
2000: 0.9767610748002905
2000: 0.9404502541757443

10: 0.4059549745824256
10: 0.45751633986928103
100: 0.9259259259259259
100: 0.8119099491648512
500: 0.9462599854756718
500: 0.8809005083514887
1000: 0.9469862018881626
1000: 0.90559186637618
2000: 0.9549745824255628
2000: 0.9172113289760349
'''


data = [float(x) for x in N_random.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# # global params
# trained =  False # loads models with random weight and not pretrained weights
# case = 'unnormalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'CIFAR10' #'Bees' #'CIFAR10'

# num_data = 10000 if which_db=='Bees' else 1000
# epochs = 10 if which_db=='Bees' else 6

# %%
# Random weights (loading models with pertained = False). [no training]  

# UnNormalized
LN_random_un = [0.9992737835875091, 	0.9992737835875091	,	0.9992737835875091]
RBF_random_un = [0.6303558460421206, 	0.6368917937545389	,	0.6332607116920842]

N_random = '''
10: 0.48366013071895425
10: 0.32679738562091504
100: 0.9803921568627451
100: 0.5555555555555556
500: 0.9985475671750181
500: 0.579520697167756
1000: 0.9992737835875091
1000: 0.6187363834422658
2000: 0.9992737835875091
2000: 0.6151053013798112



10: 0.6427015250544662
10: 0.439360929557008
100: 0.888162672476398
100: 0.5548293391430646
500: 0.9992737835875091
500: 0.5831517792302106
1000: 0.9992737835875091
1000: 0.599128540305011
2000: 0.9992737835875091
2000: 0.6274509803921569


10: 0.36528685548293394
10: 0.2636165577342048
100: 0.9956427015250545
100: 0.5555555555555556
500: 0.9992737835875091
500: 0.6151053013798112
1000: 0.9992737835875091
1000: 0.6187363834422658
2000: 0.9992737835875091
2000: 0.6310820624546115
'''


data = [float(x) for x in N_random.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# Original
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(.5, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# # Over CIFAR 10 dataset

# %%
# # global params
# trained =  False # loads models with random weight and not pretrained weights
# case = 'normalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'CIFAR10' #'Bees' #'CIFAR10'

# num_data = 10000 if which_db=='Bees' else 1000
# epochs = 10 if which_db=='Bees' else 6

# %%
# Normalized
# Run 1, 2 ..
LN_trained_n = [0.9710821933044155,		0.9804248693137582	,	0.9775330886441997]
RBF_trained_n = [0.9469469469469469	,	0.964186408630853	,	0.9552886219552886]


N_pertained = '''
10: 0.5263040818596374
10: 0.5555555555555556
100: 0.8862195528862196
100: 0.8268268268268268
500: 0.9506172839506173
500: 0.9154710265821377
1000: 0.9568457346235124
1000: 0.9202535869202536
2000: 0.9635190746301857
2000: 0.9523968412857302

10: 0.513402291180069
10: 0.5525525525525525
100: 0.9624068512957402
100: 0.905127349571794
500: 0.958180402624847
500: 0.9373818262707152
1000: 0.9656322989656323
1000: 0.9427204982760539
2000: 0.9740851963074185
2000: 0.9523968412857302

10: 0.5645645645645646
10: 0.5563341118896674
100: 0.9362696029362696
100: 0.9379379379379379
500: 0.9506172839506173
500: 0.9219219219219219
1000: 0.9628517406295184
1000: 0.9374930486041597
2000: 0.9706373039706373
2000: 0.9412746079412746
'''

# %%
# data

# %%
data = [float(x) for x in N_pertained.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]  


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)


# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# # global params
# trained =  False # loads models with random weight and not pretrained weights
# case = 'unnormalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'CIFAR10' #'Bees' #'CIFAR10'

# %%
# UnNormalized
# Run 1, 2 ..
LN_trained_un = [1.0	,	1.0,  1.0]
RBF_trained_un = [0.6474252029807586,		0.6502057613168725,	0.6434211989767545] 

N_pertained_un = '''
10: 0.5733511289066845
10: 0.2222222222222222
100: 0.9612946279612946
100: 0.5557780002224446
500: 0.9994438883327772
500: 0.5685685685685685
1000: 0.9996663329996663
1000: 0.6017128239350461
2000: 0.9998887776665555
2000: 0.6146146146146146


10: 0.22211099988877767
10: 0.3333333333333333
100: 0.8566344121899677
100: 0.5552218885552219
500: 0.9968857746635524
500: 0.5731286842397953
1000: 1.0
1000: 0.6000444889333778
2000: 1.0
2000: 0.609498387276165


10: 0.5270826381937493
10: 0.2222222222222222
100: 0.877099321543766
100: 0.5532198865532199
500: 0.9992214436658882
500: 0.5743521299076855
1000: 0.9997775553331109
1000: 0.6026026026026026
2000: 1.0
2000: 0.6189522856189523
'''

# %%
data = [float(x) for x in N_pertained_un.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]

# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('pretrained weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .13, r'chance level', fontsize=15)

plt.show()

# %%
# Original
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_trained_n, LN_trained_un]], yerr=[np.array(x).std() for x in [LN_trained_n, LN_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_trained_n, RBF_trained_un]], yerr=[np.array(x).std() for x in [RBF_trained_n, RBF_trained_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('pretrained weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(.5, .13, r'chance level', fontsize=15)

plt.show()

# %% [markdown]
# ### Random weights

# %%
# trained =  True # loads models with random weight and not pretrained weights
# case = 'normalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'CIFAR10' #'Bees' #'CIFAR10

# %%
# Random weights (loading models with pertained = False). [no training]  

# Normalized
LN_random_n = [0.9237014792570348	,		0.9274830385941497,		0.9225892559225892]
RBF_random_n = [0.3782671560449338,		0.3778222667111556	,	0.37693248804359913]

N_random = '''
10: 0.26804582360137913
10: 0.21032143254365476
100: 0.6198420642865087
100: 0.2593704815927038
500: 0.8157045934823712
500: 0.31375820264709153
1000: 0.8467356245134023
1000: 0.3624735846958069
2000: 0.8785452118785452
2000: 0.3672561450339228


10: 0.2250027805583361
10: 0.23879434990546103
100: 0.6305194082971861
100: 0.2988544099655211
500: 0.8197085974863753
500: 0.34356578801023246
1000: 0.8509620731842954
1000: 0.355689022355689
2000: 0.8883327772216661
2000: 0.36658881103325547


10: 0.2810588366143922
10: 0.12779446112779447
100: 0.6502057613168725
100: 0.32198865532198867
500: 0.8039150261372484
500: 0.34579023467912356
1000: 0.859081303525748
1000: 0.35613391168946723
2000: 0.884106328550773
2000: 0.3642531420309198
'''


data = [float(x) for x in N_random.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, normalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# # global params
# trained =  True # loads models with random weight and not pretrained weights
# case = 'unnormalized'
# only_tune_last_layer = False
# train_models = False
# # epochs = 10 # for Bees and 6 for CIFAR
# which_db = 'CIFAR10' #'Bees' #'CIFAR10'

# %%
# Random weights (loading models with pertained = False). [no training]  

# UnNormalized
LN_random_un = [0.9995551106662218,	0.9993326659993327	,	0.9987765543321099]
# RBF_random_un = [0.2521410299188077,	0.24769213658102546	,	0.25325325325325326]
RBF_random_un = [0.6338560783005227, 0.6359693026359693, 0.6467578689800912]


N_random = '''
10: 0.31286842397953507
10: 0.22211099988877767
100: 0.5636747858970081
100: 0.5551106662217773
500: 0.9332665999332665
500: 0.5980424869313758
1000: 0.9838727616505394
1000: 0.5975975975975976
2000: 0.9945501056612168
2000: 0.6068290512734957




10: 0.2752752752752753
10: 0.3333333333333333
100: 0.5700144589033478
100: 0.555444333222111
500: 0.9107996885774664
500: 0.5881436992548104
1000: 0.9797575353130908
1000: 0.5568902235568902
2000: 0.9941052163274385
2000: 0.6244021799577355


10: 0.2233344455566678
10: 0.12523634745856968
100: 0.5577800022244467
100: 0.5675675675675675
500: 0.9417194972750529
500: 0.5848070292514737
1000: 0.983983983983984
1000: 0.6111667222778334
2000: 0.9927705483261039
2000: 0.6217328439550662


'''


data = [float(x) for x in N_random.split()[1::2]]
SVM_l = np.array(data).reshape(3,-1)[:,::2]
SVM_r = np.array(data).reshape(3,-1)[:,1::2]


# Build the plot
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1,2,3,4], SVM_l.mean(axis=0) , yerr=SVM_l.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1,2,3,4]) + .4, SVM_r.mean(axis=0) , yerr=SVM_r.std(axis=0), width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
ax.set_xlabel('Num training data')
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([10,100,500,1000, 2000])
ax.set_title('random weights, unnormalized logits ')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])
# plt.savefig('res.png')

plt.plot([0,1,2,3,4,4.5], [1/9]*6,linewidth=3)
plt.text(1, .15, r'chance level', fontsize=15)

plt.show()

# %%
# Original
fig, ax = plt.subplots(figsize=(8,5))
plt.rcParams.update({'font.size': 15})

ax.bar([0,1], [np.array(x).mean() for x in [LN_random_n, LN_random_un]], yerr=[np.array(x).std() for x in [LN_random_n, LN_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.bar(np.array([0,1])+.4, [np.array(x).mean() for x in [RBF_random_n, RBF_random_un]], yerr=[np.array(x).std() for x in [RBF_random_n, RBF_random_un]], width=0.4, align='center', alpha=0.5, ecolor='black', capsize=15)
ax.set_ylabel('Acc')
# ax.set_xlabel('Num training data')
ax.set_xticks([0.2,1.2])
ax.set_xticklabels(['normalized logits', 'unnormalized logits'])

ax.set_title('random weights')
ax.yaxis.grid(True)
# plt.ylim(0,100)

# Save the figure and show
plt.tight_layout()
plt.legend(['svm - linear kernel', 'svm - RBF kernel'])

# plt.savefig('res.png')

plt.plot([0,1,1.4], [1/9]*3,linewidth=3)
plt.text(.5, .13, r'chance level', fontsize=15)

plt.show()
